# %%
import seaborn as sns
import numpy as np

# %%
kmeans_output = [0.7474022117590432, 0.767498776309349, 0.845347438542726, 0.6678138733017649, 
                 0.7451786588350465, 0.5226997800940687, 0.7010827882682861, 0.7244754555092581, 
                 0.6525087413618825, 0.7502256732951808, 0.6069977062554096, 0.7085346008631724, 
                 0.7848361866473047, 0.7168993152350959, 0.6101064051110766, 0.6687676009118948, 
                 0.7554234012221787, 0.6801956376465809, 0.6733453637328028, 0.7268657580415893, 
                 0.7309745094414575, 0.6912867025809155, 0.7318720875761237, 0.5998021233096422, 
                 0.7133805074089598, 0.6559254193305305, 0.6714642702984488, 0.7220429467047705, 
                 0.7172914082095638, 0.8726029234276519, 0.6810944620520226, 0.6187254709265094, 
                 0.6462086664565553, 0.7879779794673413, 0.6711957241259309, 0.6745975123755511, 
                 0.6417858230374022, 0.7466605543498828, 0.6558718234939735, 0.7385635270603224, 
                 0.7790677693467513, 0.6598900553077793, 0.5900848078056871, 0.6420052056597962, 
                 0.8005817983919558, 0.6053944285474039, 0.6724075173853905, 0.6018951568355301, 
                 0.6886900120908053, 0.6082796288707998, 0.7246344885158089, 0.8474101329218686, 
                 0.6179835379861547, 0.6304751411722359, 0.7892003555546246, 0.8153171256629013, 
                 0.7812265761168959, 0.6842338516083761, 0.6190647382539199, 0.6789082260654465, 
                 0.6937459703417151, 0.7093392930214989, 0.7139781218352842, 0.7466621304809934, 
                 0.7093392930214989, 0.6156015049666727, 0.6676363306532598, 0.6725283688793993, 
                 0.6205450464067717, 0.8001903867552567, 0.6357570416490221, 0.6634983315550599, 
                 0.5857703037985982, 0.6965026546054183, 0.7302985805188449, 0.830739109153206, 
                 0.6485499473981007, 0.5597975541576671, 0.6159353154215446, 0.5922653451295024, 
                 0.7541179684732437, 0.6227453066310118, 0.7556216511296976, 0.6261619162719855, 
                 0.6051577425692424, 0.6088240407528879, 0.7222211392637008, 0.8518512742739738, 
                 0.6492515708912918, 0.7065654892621579, 0.5865112804265594, 0.7074062666910982, 
                 0.7068390632823932, 0.701631987105287, 0.8105569378389544, 0.8153535170295887, 
                 0.7258283903697145, 0.7333198721018851, 0.6810494448501716, 0.7065654892621579]

# %%
anzahl = len(kmeans_output)
schnitt = sum(kmeans_output) / anzahl

print("anzahl werte: " + str(anzahl))
print("schnitt: " + str(schnitt))
# Out:
# anzahl werte: 100
# schnitt: 0.6944854134690372

# %%
n = 5

werte_mit_verrechnung = [kmeans_output[i * n:(i + 1) * n] for i in range((len(kmeans_output) + n - 1) // n )] 

werte_mit_verrechnung = [sum(x) / n for x in werte_mit_verrechnung]

print(werte_mit_verrechnung)
# Out:
# [0.754648191749586, 0.6701984877057352, 0.6854748428224119, 0.7009195523110092, 0.6934631860634197, 0.7278653935941931, 0.6810404606056719, 0.6914958480634266, 0.694325927302394, 0.6353333487459859, 0.7219407312301385, 0.7157501035415079, 0.7146129617401982, 0.6753003275322721, 0.6623653824253887, 0.6494574542520042, 0.6727609170150363, 0.7077427028888024, 0.7025891070688585, 0.7324233427227036]

# %%
sns.distplot(werte_mit_verrechnung);

# %%
varianz = np.var(kmeans_output)
standardabweichung = np.std(kmeans_output)

print("varianz: " + str(varianz))
print("standardabweichung: " + str(standardabweichung))
# Out:
# varianz: 0.005058895896248217
# standardabweichung: 0.07112591578495293
